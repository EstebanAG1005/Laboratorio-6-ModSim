# %%
import random

# %% [markdown]
# ### Creacion de la Clase Vehiculo

# %%
class Vehiculo:
    def __init__(self, tipo_vehiculo="coche", velocidad_maxima=100):
        # Inicializa las propiedades del vehículo
        self.tipo_vehiculo = tipo_vehiculo
        self.velocidad_maxima = velocidad_maxima
        self.velocidad_actual = 0
        self.destino = None
        # El comportamiento se elige al azar entre: cauteloso, normal y agresivo
        self.comportamiento = random.choice(["cauteloso", "normal", "agresivo"])

    def acelerar(self):
        # Si la velocidad actual es menor que la máxima, el vehículo acelera
        # La cantidad de aceleración depende del comportamiento del vehículo
        if self.velocidad_actual < self.velocidad_maxima:
            incremento = (
                5 if self.comportamiento == "cauteloso" else
                15 if self.comportamiento == "agresivo" else
                10
            )
            self.velocidad_actual += incremento

    def desacelerar(self):
        # Decrementa la velocidad según el comportamiento del vehículo
        decremento = (
            5 if self.comportamiento == "agresivo" else
            15 if self.comportamiento == "cauteloso" else
            10
        )
        if self.velocidad_actual - decremento >= 0:
            self.velocidad_actual -= decremento

# %% [markdown]
# ### Creacion de la Clase SegmentoCarretera

# %%
class SegmentoCarretera:
    def __init__(self, capacidad, limite_velocidad):
        # Propiedades de un segmento de carretera
        self.vehiculos = []
        self.capacidad = capacidad
        self.limite_velocidad = limite_velocidad
        self.congestion = False

    def agregar_vehiculo(self, vehiculo):
        # Agrega un vehículo al segmento si no ha alcanzado su capacidad
        if len(self.vehiculos) < self.capacidad:
            self.vehiculos.append(vehiculo)
            vehiculo.destino = self

    def flujo_vehiculos(self):
        # Gestiona el flujo de vehículos en el segmento
        for vehiculo in self.vehiculos:
            if len(self.vehiculos) > 0.8 * self.capacidad:
                # Si hay congestión, desacelera los vehículos
                self.congestion = True
                vehiculo.desacelerar()
            elif vehiculo.velocidad_actual < self.limite_velocidad and not self.congestion:
                # Si no hay congestión y la velocidad es menor al límite, acelera
                vehiculo.acelerar()

    def num_vehiculos(self):
        # Retorna el número de vehículos en el segmento
        return len(self.vehiculos)

    def mover_vehiculos_a_interseccion(self, interseccion):
        # Mueve el primer vehículo del segmento a la intersección
        if self.vehiculos:
            vehiculo = self.vehiculos.pop(0)
            interseccion.vehiculos_esperando.append(vehiculo)

# %% [markdown]
# ### Creacion de la Clase Interseccion

# %%
class Interseccion:
    def __init__(self):
        # Propiedades de una intersección: semáforo y vehículos esperando
        self.vehiculos_esperando = []
        self.semaforo = random.choice(["rojo", "verde"])
        self.tiempo_semaforo = 0  # Contador para cambiar el semáforo

    def cambiar_semaforo(self):
        # Cambia el semáforo de rojo a verde o viceversa cada 10 ciclos
        if self.tiempo_semaforo >= 10:
            self.semaforo = "verde" if self.semaforo == "rojo" else "rojo"
            self.tiempo_semaforo = 0
        self.tiempo_semaforo += 1

    def manejar_interseccion(self, siguiente_segmento=None):
        # Si el semáforo está en verde y hay vehículos esperando, mueve el vehículo al siguiente segmento
        if self.semaforo == "verde" and self.vehiculos_esperando:
            vehiculo = self.vehiculos_esperando.pop(0)
            if siguiente_segmento:
                siguiente_segmento.agregar_vehiculo(vehiculo)

# %% [markdown]
# ### Creacion de la Clase Calle

# %%
class Calle:
    def __init__(self, num_segmentos, capacidad_segmento, limite_velocidad):
        # Una calle tiene varios segmentos y intersecciones
        self.segmentos = [SegmentoCarretera(capacidad_segmento, limite_velocidad) for _ in range(num_segmentos)]
        self.intersecciones = [Interseccion() for _ in range(num_segmentos + 1)]

    def flujo_en_calle(self):
        # Gestiona el flujo de vehículos y semáforos en cada segmento y intersección de la calle
        for i, segmento in enumerate(self.segmentos):
            segmento.flujo_vehiculos()
            self.intersecciones[i].cambiar_semaforo()
            segmento.mover_vehiculos_a_interseccion(self.intersecciones[i])
            siguiente_segmento = self.segmentos[i + 1] if i + 1 < len(self.segmentos) else None
            self.intersecciones[i].manejar_interseccion(siguiente_segmento)

# %% [markdown]
# ### Creacion de la Clase Vecindario

# %%
class Vecindario:
    def __init__(self, num_calles, num_segmentos_por_calle, capacidad_segmento, limite_velocidad):
        # Un vecindario tiene varias calles
        self.calles = [Calle(num_segmentos_por_calle, capacidad_segmento, limite_velocidad) for _ in range(num_calles)]

    def flujo_en_vecindario(self):
        # Gestiona el flujo de vehículos en cada calle del vecindario
        for calle in self.calles:
            calle.flujo_en_calle()

# %% [markdown]
# ### Creacion de la Clase Ciudad

# %%
class Ciudad:
    def __init__(self, num_vecindarios, num_calles_por_vecindario, num_segmentos_por_calle, capacidad_segmento, limite_velocidad):
        # Una ciudad tiene varios vecindarios
        self.vecindarios = [
            Vecindario(num_calles_por_vecindario, num_segmentos_por_calle, capacidad_segmento, limite_velocidad)
            for _ in range(num_vecindarios)
        ]

    def flujo_en_ciudad(self):
        # Gestiona el flujo de vehículos en cada vecindario de la ciudad
        for vecindario in self.vecindarios:
            vecindario.flujo_en_vecindario()

    def introducir_vehiculos(self, num_vehiculos):
        # Introduce vehículos aleatoriamente en la ciudad
        for _ in range(num_vehiculos):
            vecindario_aleatorio = random.choice(self.vecindarios)
            calle_aleatoria = random.choice(vecindario_aleatorio.calles)
            segmento_aleatorio = random.choice(calle_aleatoria.segmentos)
            vehiculo = Vehiculo()
            segmento_aleatorio.agregar_vehiculo(vehiculo)

# %% [markdown]
# ### Inicialización de las variables para la simulación

# %%
# Creación de la ciudad con estructura deseada
ciudad = Ciudad(
    num_vecindarios=3,
    num_calles_por_vecindario=5,
    num_segmentos_por_calle=4,
    capacidad_segmento=100,
    limite_velocidad=60,
)

# Introducir vehículos al inicio de la simulación
ciudad.introducir_vehiculos(5000)  # Introduce 500 vehículos aleatoriamente en la ciudad

# Creación de una lista para almacenar el número de vehículos en cada segmento después de cada ciclo
historial_vehiculos = []

# Simulación por un número determinado de ciclos
num_ciclos = 100
for _ in range(num_ciclos):
    ciudad.flujo_en_ciudad()
    vehiculos_por_ciclo = []
    for vecindario in ciudad.vecindarios:
        for calle in vecindario.calles:
            for segmento in calle.segmentos:
                vehiculos_por_ciclo.append(segmento.num_vehiculos())
    historial_vehiculos.append(vehiculos_por_ciclo)

# %% [markdown]
# ### Creacion de Simulación

# %%
# Creación de un diccionario para almacenar de forma estructurada los datos
resultados = {}

# Llenamos el diccionario con los resultados
for ciclo in range(num_ciclos):
    resultados[f"Ciclo {ciclo + 1}"] = {}
    idx = 0  # para avanzar por la lista historial_vehiculos
    for v, vecindario in enumerate(ciudad.vecindarios, 1):
        resultados[f"Ciclo {ciclo + 1}"][f"Vecindario {v}"] = {}
        for c, calle in enumerate(vecindario.calles, 1):
            resultados[f"Ciclo {ciclo + 1}"][f"Vecindario {v}"][f"Calle {c}"] = {}
            for s, segmento in enumerate(calle.segmentos, 1):
                resultados[f"Ciclo {ciclo + 1}"][f"Vecindario {v}"][f"Calle {c}"][
                    f"Segmento {s}"
                ] = historial_vehiculos[ciclo][idx]
                idx += 1

# Función para imprimir los resultados de forma estructurada
def imprimir_resultados(resultados):
    for ciclo, datos_ciclo in resultados.items():
        print(f"--- {ciclo} ---")
        for vecindario, datos_vecindario in datos_ciclo.items():
            total_vehiculos_vecindario = sum(
                sum(datos_calle.values()) for datos_calle in datos_vecindario.values()
            )
            print(f"{vecindario} - Total Vehículos: {total_vehiculos_vecindario}")
            for calle, datos_calle in datos_vecindario.items():
                total_vehiculos_calle = sum(datos_calle.values())
                print(f"  {calle} - Total Vehículos: {total_vehiculos_calle}")
                for segmento, num_vehiculos in datos_calle.items():
                    print(f"    {segmento}: {num_vehiculos} vehículos")
        print("\n")


imprimir_resultados(resultados)
# Out:
# --- Ciclo 1 ---
# Vecindario 1 - Total Vehículos: 1650
#   Calle 1 - Total Vehículos: 329
#     Segmento 1: 81 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 78 vehículos
#   Calle 2 - Total Vehículos: 318
#     Segmento 1: 82 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 79 vehículos
#   Calle 3 - Total Vehículos: 309
#     Segmento 1: 72 vehículos
#     Segmento 2: 83 vehículos
#     Segmento 3: 70 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 343
#     Segmento 1: 89 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 351
#     Segmento 1: 79 vehículos
#     Segmento 2: 89 vehículos
#     Segmento 3: 90 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1653
#   Calle 1 - Total Vehículos: 336
#     Segmento 1: 98 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 78 vehículos
#   Calle 2 - Total Vehículos: 353
#     Segmento 1: 94 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 87 vehículos
#   Calle 3 - Total Vehículos: 331
#     Segmento 1: 86 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 295
#     Segmento 1: 78 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 84 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 338
#     Segmento 1: 93 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1657
#   Calle 1 - Total Vehículos: 327
#     Segmento 1: 74 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 88 vehículos
#     Segmento 4: 74 vehículos
#   Calle 2 - Total Vehículos: 339
#     Segmento 1: 84 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 342
#     Segmento 1: 87 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 92 vehículos
#   Calle 4 - Total Vehículos: 320
#     Segmento 1: 66 vehículos
#     Segmento 2: 76 vehículos
#     Segmento 3: 87 vehículos
#     Segmento 4: 91 vehículos
#   Calle 5 - Total Vehículos: 329
#     Segmento 1: 81 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 66 vehículos
#
#
# --- Ciclo 2 ---
# Vecindario 1 - Total Vehículos: 1637
#   Calle 1 - Total Vehículos: 326
#     Segmento 1: 80 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 94 vehículos
#     Segmento 4: 77 vehículos
#   Calle 2 - Total Vehículos: 315
#     Segmento 1: 81 vehículos
#     Segmento 2: 76 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 306
#     Segmento 1: 71 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 69 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 342
#     Segmento 1: 88 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 348
#     Segmento 1: 78 vehículos
#     Segmento 2: 88 vehículos
#     Segmento 3: 89 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1642
#   Calle 1 - Total Vehículos: 333
#     Segmento 1: 97 vehículos
#     Segmento 2: 81 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 77 vehículos
#   Calle 2 - Total Vehículos: 350
#     Segmento 1: 93 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 86 vehículos
#   Calle 3 - Total Vehículos: 330
#     Segmento 1: 85 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 293
#     Segmento 1: 77 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 336
#     Segmento 1: 92 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1643
#   Calle 1 - Total Vehículos: 324
#     Segmento 1: 73 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 87 vehículos
#     Segmento 4: 73 vehículos
#   Calle 2 - Total Vehículos: 337
#     Segmento 1: 83 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 85 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 339
#     Segmento 1: 86 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 91 vehículos
#   Calle 4 - Total Vehículos: 316
#     Segmento 1: 65 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 90 vehículos
#   Calle 5 - Total Vehículos: 327
#     Segmento 1: 80 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 65 vehículos
#
#
# --- Ciclo 3 ---
# Vecindario 1 - Total Vehículos: 1624
#   Calle 1 - Total Vehículos: 323
#     Segmento 1: 79 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 93 vehículos
#     Segmento 4: 76 vehículos
#   Calle 2 - Total Vehículos: 312
#     Segmento 1: 80 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 77 vehículos
#   Calle 3 - Total Vehículos: 303
#     Segmento 1: 70 vehículos
#     Segmento 2: 81 vehículos
#     Segmento 3: 68 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 341
#     Segmento 1: 87 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 345
#     Segmento 1: 77 vehículos
#     Segmento 2: 87 vehículos
#     Segmento 3: 88 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1631
#   Calle 1 - Total Vehículos: 330
#     Segmento 1: 96 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 76 vehículos
#   Calle 2 - Total Vehículos: 347
#     Segmento 1: 92 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 85 vehículos
#   Calle 3 - Total Vehículos: 329
#     Segmento 1: 84 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 291
#     Segmento 1: 76 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 334
#     Segmento 1: 91 vehículos
#     Segmento 2: 89 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1629
#   Calle 1 - Total Vehículos: 321
#     Segmento 1: 72 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 72 vehículos
#   Calle 2 - Total Vehículos: 335
#     Segmento 1: 82 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 84 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 336
#     Segmento 1: 85 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 71 vehículos
#     Segmento 4: 90 vehículos
#   Calle 4 - Total Vehículos: 312
#     Segmento 1: 64 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 85 vehículos
#     Segmento 4: 89 vehículos
#   Calle 5 - Total Vehículos: 325
#     Segmento 1: 79 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 64 vehículos
#
#
# --- Ciclo 4 ---
# Vecindario 1 - Total Vehículos: 1611
#   Calle 1 - Total Vehículos: 320
#     Segmento 1: 78 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 92 vehículos
#     Segmento 4: 75 vehículos
#   Calle 2 - Total Vehículos: 309
#     Segmento 1: 79 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 76 vehículos
#   Calle 3 - Total Vehículos: 300
#     Segmento 1: 69 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 67 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 340
#     Segmento 1: 86 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 342
#     Segmento 1: 76 vehículos
#     Segmento 2: 86 vehículos
#     Segmento 3: 87 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1620
#   Calle 1 - Total Vehículos: 327
#     Segmento 1: 95 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 75 vehículos
#   Calle 2 - Total Vehículos: 344
#     Segmento 1: 91 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 84 vehículos
#   Calle 3 - Total Vehículos: 328
#     Segmento 1: 83 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 289
#     Segmento 1: 75 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 332
#     Segmento 1: 90 vehículos
#     Segmento 2: 88 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1615
#   Calle 1 - Total Vehículos: 318
#     Segmento 1: 71 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 85 vehículos
#     Segmento 4: 71 vehículos
#   Calle 2 - Total Vehículos: 333
#     Segmento 1: 81 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 333
#     Segmento 1: 84 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 70 vehículos
#     Segmento 4: 89 vehículos
#   Calle 4 - Total Vehículos: 308
#     Segmento 1: 63 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 84 vehículos
#     Segmento 4: 88 vehículos
#   Calle 5 - Total Vehículos: 323
#     Segmento 1: 78 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 63 vehículos
#
#
# --- Ciclo 5 ---
# Vecindario 1 - Total Vehículos: 1598
#   Calle 1 - Total Vehículos: 317
#     Segmento 1: 77 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 91 vehículos
#     Segmento 4: 74 vehículos
#   Calle 2 - Total Vehículos: 306
#     Segmento 1: 78 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 75 vehículos
#   Calle 3 - Total Vehículos: 297
#     Segmento 1: 68 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 66 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 339
#     Segmento 1: 85 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 339
#     Segmento 1: 75 vehículos
#     Segmento 2: 85 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1609
#   Calle 1 - Total Vehículos: 324
#     Segmento 1: 94 vehículos
#     Segmento 2: 78 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 74 vehículos
#   Calle 2 - Total Vehículos: 341
#     Segmento 1: 90 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 83 vehículos
#   Calle 3 - Total Vehículos: 327
#     Segmento 1: 82 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 287
#     Segmento 1: 74 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 330
#     Segmento 1: 89 vehículos
#     Segmento 2: 87 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1601
#   Calle 1 - Total Vehículos: 315
#     Segmento 1: 70 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 84 vehículos
#     Segmento 4: 70 vehículos
#   Calle 2 - Total Vehículos: 331
#     Segmento 1: 80 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 330
#     Segmento 1: 83 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 69 vehículos
#     Segmento 4: 88 vehículos
#   Calle 4 - Total Vehículos: 304
#     Segmento 1: 62 vehículos
#     Segmento 2: 72 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 87 vehículos
#   Calle 5 - Total Vehículos: 321
#     Segmento 1: 77 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 62 vehículos
#
#
# --- Ciclo 6 ---
# Vecindario 1 - Total Vehículos: 1585
#   Calle 1 - Total Vehículos: 314
#     Segmento 1: 76 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 90 vehículos
#     Segmento 4: 73 vehículos
#   Calle 2 - Total Vehículos: 303
#     Segmento 1: 77 vehículos
#     Segmento 2: 72 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 74 vehículos
#   Calle 3 - Total Vehículos: 294
#     Segmento 1: 67 vehículos
#     Segmento 2: 78 vehículos
#     Segmento 3: 65 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 338
#     Segmento 1: 84 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 336
#     Segmento 1: 74 vehículos
#     Segmento 2: 84 vehículos
#     Segmento 3: 85 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1598
#   Calle 1 - Total Vehículos: 321
#     Segmento 1: 93 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 73 vehículos
#   Calle 2 - Total Vehículos: 338
#     Segmento 1: 89 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 82 vehículos
#   Calle 3 - Total Vehículos: 326
#     Segmento 1: 81 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 285
#     Segmento 1: 73 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 328
#     Segmento 1: 88 vehículos
#     Segmento 2: 86 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1587
#   Calle 1 - Total Vehículos: 312
#     Segmento 1: 69 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 329
#     Segmento 1: 79 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 327
#     Segmento 1: 82 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 68 vehículos
#     Segmento 4: 87 vehículos
#   Calle 4 - Total Vehículos: 300
#     Segmento 1: 61 vehículos
#     Segmento 2: 71 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 86 vehículos
#   Calle 5 - Total Vehículos: 319
#     Segmento 1: 76 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 61 vehículos
#
#
# --- Ciclo 7 ---
# Vecindario 1 - Total Vehículos: 1572
#   Calle 1 - Total Vehículos: 311
#     Segmento 1: 75 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 89 vehículos
#     Segmento 4: 72 vehículos
#   Calle 2 - Total Vehículos: 300
#     Segmento 1: 76 vehículos
#     Segmento 2: 71 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 73 vehículos
#   Calle 3 - Total Vehículos: 291
#     Segmento 1: 66 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 337
#     Segmento 1: 83 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 333
#     Segmento 1: 73 vehículos
#     Segmento 2: 83 vehículos
#     Segmento 3: 84 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1587
#   Calle 1 - Total Vehículos: 318
#     Segmento 1: 92 vehículos
#     Segmento 2: 76 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 72 vehículos
#   Calle 2 - Total Vehículos: 335
#     Segmento 1: 88 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 76 vehículos
#     Segmento 4: 81 vehículos
#   Calle 3 - Total Vehículos: 325
#     Segmento 1: 80 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 283
#     Segmento 1: 72 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 326
#     Segmento 1: 87 vehículos
#     Segmento 2: 85 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1573
#   Calle 1 - Total Vehículos: 309
#     Segmento 1: 68 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 68 vehículos
#   Calle 2 - Total Vehículos: 327
#     Segmento 1: 78 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 324
#     Segmento 1: 81 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 67 vehículos
#     Segmento 4: 86 vehículos
#   Calle 4 - Total Vehículos: 296
#     Segmento 1: 60 vehículos
#     Segmento 2: 70 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 85 vehículos
#   Calle 5 - Total Vehículos: 317
#     Segmento 1: 75 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 60 vehículos
#
#
# --- Ciclo 8 ---
# Vecindario 1 - Total Vehículos: 1559
#   Calle 1 - Total Vehículos: 308
#     Segmento 1: 74 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 88 vehículos
#     Segmento 4: 71 vehículos
#   Calle 2 - Total Vehículos: 297
#     Segmento 1: 75 vehículos
#     Segmento 2: 70 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 72 vehículos
#   Calle 3 - Total Vehículos: 288
#     Segmento 1: 65 vehículos
#     Segmento 2: 76 vehículos
#     Segmento 3: 63 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 336
#     Segmento 1: 82 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 330
#     Segmento 1: 72 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1576
#   Calle 1 - Total Vehículos: 315
#     Segmento 1: 91 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 71 vehículos
#   Calle 2 - Total Vehículos: 332
#     Segmento 1: 87 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 80 vehículos
#   Calle 3 - Total Vehículos: 324
#     Segmento 1: 79 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 281
#     Segmento 1: 71 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 324
#     Segmento 1: 86 vehículos
#     Segmento 2: 84 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1559
#   Calle 1 - Total Vehículos: 306
#     Segmento 1: 67 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 67 vehículos
#   Calle 2 - Total Vehículos: 325
#     Segmento 1: 77 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 321
#     Segmento 1: 80 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 66 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 292
#     Segmento 1: 59 vehículos
#     Segmento 2: 69 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 84 vehículos
#   Calle 5 - Total Vehículos: 315
#     Segmento 1: 74 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 59 vehículos
#
#
# --- Ciclo 9 ---
# Vecindario 1 - Total Vehículos: 1546
#   Calle 1 - Total Vehículos: 305
#     Segmento 1: 73 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 87 vehículos
#     Segmento 4: 70 vehículos
#   Calle 2 - Total Vehículos: 294
#     Segmento 1: 74 vehículos
#     Segmento 2: 69 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 71 vehículos
#   Calle 3 - Total Vehículos: 285
#     Segmento 1: 64 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 62 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 335
#     Segmento 1: 81 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 327
#     Segmento 1: 71 vehículos
#     Segmento 2: 81 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1565
#   Calle 1 - Total Vehículos: 312
#     Segmento 1: 90 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 70 vehículos
#   Calle 2 - Total Vehículos: 329
#     Segmento 1: 86 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 74 vehículos
#     Segmento 4: 79 vehículos
#   Calle 3 - Total Vehículos: 323
#     Segmento 1: 78 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 279
#     Segmento 1: 70 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 76 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 322
#     Segmento 1: 85 vehículos
#     Segmento 2: 83 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1545
#   Calle 1 - Total Vehículos: 303
#     Segmento 1: 66 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 66 vehículos
#   Calle 2 - Total Vehículos: 323
#     Segmento 1: 76 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 318
#     Segmento 1: 79 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 65 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 288
#     Segmento 1: 58 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 83 vehículos
#   Calle 5 - Total Vehículos: 313
#     Segmento 1: 73 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 58 vehículos
#
#
# --- Ciclo 10 ---
# Vecindario 1 - Total Vehículos: 1533
#   Calle 1 - Total Vehículos: 302
#     Segmento 1: 72 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 291
#     Segmento 1: 73 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 282
#     Segmento 1: 63 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 334
#     Segmento 1: 80 vehículos
#     Segmento 2: 79 vehículos
#     Segmento 3: 95 vehículos
#     Segmento 4: 80 vehículos
#   Calle 5 - Total Vehículos: 324
#     Segmento 1: 70 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 93 vehículos
# Vecindario 2 - Total Vehículos: 1554
#   Calle 1 - Total Vehículos: 309
#     Segmento 1: 89 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 326
#     Segmento 1: 85 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 322
#     Segmento 1: 77 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 85 vehículos
#   Calle 4 - Total Vehículos: 277
#     Segmento 1: 69 vehículos
#     Segmento 2: 63 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 320
#     Segmento 1: 84 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 82 vehículos
# Vecindario 3 - Total Vehículos: 1531
#   Calle 1 - Total Vehículos: 300
#     Segmento 1: 65 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 321
#     Segmento 1: 75 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 94 vehículos
#   Calle 3 - Total Vehículos: 315
#     Segmento 1: 78 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 284
#     Segmento 1: 57 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 311
#     Segmento 1: 72 vehículos
#     Segmento 2: 99 vehículos
#     Segmento 3: 83 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 11 ---
# Vecindario 1 - Total Vehículos: 1521
#   Calle 1 - Total Vehículos: 300
#     Segmento 1: 71 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 289
#     Segmento 1: 72 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 280
#     Segmento 1: 62 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 330
#     Segmento 1: 79 vehículos
#     Segmento 2: 78 vehículos
#     Segmento 3: 94 vehículos
#     Segmento 4: 79 vehículos
#   Calle 5 - Total Vehículos: 322
#     Segmento 1: 69 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 92 vehículos
# Vecindario 2 - Total Vehículos: 1540
#   Calle 1 - Total Vehículos: 307
#     Segmento 1: 88 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 324
#     Segmento 1: 84 vehículos
#     Segmento 2: 89 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 318
#     Segmento 1: 76 vehículos
#     Segmento 2: 76 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 84 vehículos
#   Calle 4 - Total Vehículos: 274
#     Segmento 1: 68 vehículos
#     Segmento 2: 62 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 69 vehículos
#   Calle 5 - Total Vehículos: 317
#     Segmento 1: 83 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 71 vehículos
#     Segmento 4: 81 vehículos
# Vecindario 3 - Total Vehículos: 1520
#   Calle 1 - Total Vehículos: 298
#     Segmento 1: 64 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 318
#     Segmento 1: 74 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 93 vehículos
#   Calle 3 - Total Vehículos: 313
#     Segmento 1: 77 vehículos
#     Segmento 2: 89 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 283
#     Segmento 1: 56 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 308
#     Segmento 1: 71 vehículos
#     Segmento 2: 98 vehículos
#     Segmento 3: 82 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 12 ---
# Vecindario 1 - Total Vehículos: 1509
#   Calle 1 - Total Vehículos: 298
#     Segmento 1: 70 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 287
#     Segmento 1: 71 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 278
#     Segmento 1: 61 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 82 vehículos
#   Calle 4 - Total Vehículos: 326
#     Segmento 1: 78 vehículos
#     Segmento 2: 77 vehículos
#     Segmento 3: 93 vehículos
#     Segmento 4: 78 vehículos
#   Calle 5 - Total Vehículos: 320
#     Segmento 1: 68 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 91 vehículos
# Vecindario 2 - Total Vehículos: 1526
#   Calle 1 - Total Vehículos: 305
#     Segmento 1: 87 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 76 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 322
#     Segmento 1: 83 vehículos
#     Segmento 2: 88 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 314
#     Segmento 1: 75 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 271
#     Segmento 1: 67 vehículos
#     Segmento 2: 61 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 68 vehículos
#   Calle 5 - Total Vehículos: 314
#     Segmento 1: 82 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 70 vehículos
#     Segmento 4: 80 vehículos
# Vecindario 3 - Total Vehículos: 1509
#   Calle 1 - Total Vehículos: 296
#     Segmento 1: 63 vehículos
#     Segmento 2: 89 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 315
#     Segmento 1: 73 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 92 vehículos
#   Calle 3 - Total Vehículos: 311
#     Segmento 1: 76 vehículos
#     Segmento 2: 88 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 282
#     Segmento 1: 55 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 305
#     Segmento 1: 70 vehículos
#     Segmento 2: 97 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 13 ---
# Vecindario 1 - Total Vehículos: 1497
#   Calle 1 - Total Vehículos: 296
#     Segmento 1: 69 vehículos
#     Segmento 2: 72 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 285
#     Segmento 1: 70 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 276
#     Segmento 1: 60 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 81 vehículos
#   Calle 4 - Total Vehículos: 322
#     Segmento 1: 77 vehículos
#     Segmento 2: 76 vehículos
#     Segmento 3: 92 vehículos
#     Segmento 4: 77 vehículos
#   Calle 5 - Total Vehículos: 318
#     Segmento 1: 67 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 90 vehículos
# Vecindario 2 - Total Vehículos: 1512
#   Calle 1 - Total Vehículos: 303
#     Segmento 1: 86 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 320
#     Segmento 1: 82 vehículos
#     Segmento 2: 87 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 310
#     Segmento 1: 74 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 82 vehículos
#   Calle 4 - Total Vehículos: 268
#     Segmento 1: 66 vehículos
#     Segmento 2: 60 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 67 vehículos
#   Calle 5 - Total Vehículos: 311
#     Segmento 1: 81 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 69 vehículos
#     Segmento 4: 79 vehículos
# Vecindario 3 - Total Vehículos: 1498
#   Calle 1 - Total Vehículos: 294
#     Segmento 1: 62 vehículos
#     Segmento 2: 88 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 312
#     Segmento 1: 72 vehículos
#     Segmento 2: 72 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 91 vehículos
#   Calle 3 - Total Vehículos: 309
#     Segmento 1: 75 vehículos
#     Segmento 2: 87 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 281
#     Segmento 1: 54 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 302
#     Segmento 1: 69 vehículos
#     Segmento 2: 96 vehículos
#     Segmento 3: 80 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 14 ---
# Vecindario 1 - Total Vehículos: 1485
#   Calle 1 - Total Vehículos: 294
#     Segmento 1: 68 vehículos
#     Segmento 2: 71 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 283
#     Segmento 1: 69 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 76 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 274
#     Segmento 1: 59 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 80 vehículos
#   Calle 4 - Total Vehículos: 318
#     Segmento 1: 76 vehículos
#     Segmento 2: 75 vehículos
#     Segmento 3: 91 vehículos
#     Segmento 4: 76 vehículos
#   Calle 5 - Total Vehículos: 316
#     Segmento 1: 66 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 89 vehículos
# Vecindario 2 - Total Vehículos: 1498
#   Calle 1 - Total Vehículos: 301
#     Segmento 1: 85 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 74 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 318
#     Segmento 1: 81 vehículos
#     Segmento 2: 86 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 306
#     Segmento 1: 73 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 81 vehículos
#   Calle 4 - Total Vehículos: 265
#     Segmento 1: 65 vehículos
#     Segmento 2: 59 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 66 vehículos
#   Calle 5 - Total Vehículos: 308
#     Segmento 1: 80 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 68 vehículos
#     Segmento 4: 78 vehículos
# Vecindario 3 - Total Vehículos: 1487
#   Calle 1 - Total Vehículos: 292
#     Segmento 1: 61 vehículos
#     Segmento 2: 87 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 309
#     Segmento 1: 71 vehículos
#     Segmento 2: 71 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 90 vehículos
#   Calle 3 - Total Vehículos: 307
#     Segmento 1: 74 vehículos
#     Segmento 2: 86 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 280
#     Segmento 1: 53 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 299
#     Segmento 1: 68 vehículos
#     Segmento 2: 95 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 15 ---
# Vecindario 1 - Total Vehículos: 1473
#   Calle 1 - Total Vehículos: 292
#     Segmento 1: 67 vehículos
#     Segmento 2: 70 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 281
#     Segmento 1: 68 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 272
#     Segmento 1: 58 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 79 vehículos
#   Calle 4 - Total Vehículos: 314
#     Segmento 1: 75 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 90 vehículos
#     Segmento 4: 75 vehículos
#   Calle 5 - Total Vehículos: 314
#     Segmento 1: 65 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 88 vehículos
# Vecindario 2 - Total Vehículos: 1484
#   Calle 1 - Total Vehículos: 299
#     Segmento 1: 84 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 316
#     Segmento 1: 80 vehículos
#     Segmento 2: 85 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 302
#     Segmento 1: 72 vehículos
#     Segmento 2: 72 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 80 vehículos
#   Calle 4 - Total Vehículos: 262
#     Segmento 1: 64 vehículos
#     Segmento 2: 58 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 65 vehículos
#   Calle 5 - Total Vehículos: 305
#     Segmento 1: 79 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 67 vehículos
#     Segmento 4: 77 vehículos
# Vecindario 3 - Total Vehículos: 1476
#   Calle 1 - Total Vehículos: 290
#     Segmento 1: 60 vehículos
#     Segmento 2: 86 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 306
#     Segmento 1: 70 vehículos
#     Segmento 2: 70 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 89 vehículos
#   Calle 3 - Total Vehículos: 305
#     Segmento 1: 73 vehículos
#     Segmento 2: 85 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 279
#     Segmento 1: 52 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 296
#     Segmento 1: 67 vehículos
#     Segmento 2: 94 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 16 ---
# Vecindario 1 - Total Vehículos: 1461
#   Calle 1 - Total Vehículos: 290
#     Segmento 1: 66 vehículos
#     Segmento 2: 69 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 279
#     Segmento 1: 67 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 74 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 270
#     Segmento 1: 57 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 78 vehículos
#   Calle 4 - Total Vehículos: 310
#     Segmento 1: 74 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 89 vehículos
#     Segmento 4: 74 vehículos
#   Calle 5 - Total Vehículos: 312
#     Segmento 1: 64 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 87 vehículos
# Vecindario 2 - Total Vehículos: 1470
#   Calle 1 - Total Vehículos: 297
#     Segmento 1: 83 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 314
#     Segmento 1: 79 vehículos
#     Segmento 2: 84 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 298
#     Segmento 1: 71 vehículos
#     Segmento 2: 71 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 79 vehículos
#   Calle 4 - Total Vehículos: 259
#     Segmento 1: 63 vehículos
#     Segmento 2: 57 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 64 vehículos
#   Calle 5 - Total Vehículos: 302
#     Segmento 1: 78 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 66 vehículos
#     Segmento 4: 76 vehículos
# Vecindario 3 - Total Vehículos: 1465
#   Calle 1 - Total Vehículos: 288
#     Segmento 1: 59 vehículos
#     Segmento 2: 85 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 303
#     Segmento 1: 69 vehículos
#     Segmento 2: 69 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 88 vehículos
#   Calle 3 - Total Vehículos: 303
#     Segmento 1: 72 vehículos
#     Segmento 2: 84 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 278
#     Segmento 1: 51 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 293
#     Segmento 1: 66 vehículos
#     Segmento 2: 93 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 17 ---
# Vecindario 1 - Total Vehículos: 1449
#   Calle 1 - Total Vehículos: 288
#     Segmento 1: 65 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 277
#     Segmento 1: 66 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 268
#     Segmento 1: 56 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 77 vehículos
#   Calle 4 - Total Vehículos: 306
#     Segmento 1: 73 vehículos
#     Segmento 2: 72 vehículos
#     Segmento 3: 88 vehículos
#     Segmento 4: 73 vehículos
#   Calle 5 - Total Vehículos: 310
#     Segmento 1: 63 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 86 vehículos
# Vecindario 2 - Total Vehículos: 1456
#   Calle 1 - Total Vehículos: 295
#     Segmento 1: 82 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 71 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 312
#     Segmento 1: 78 vehículos
#     Segmento 2: 83 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 294
#     Segmento 1: 70 vehículos
#     Segmento 2: 70 vehículos
#     Segmento 3: 76 vehículos
#     Segmento 4: 78 vehículos
#   Calle 4 - Total Vehículos: 256
#     Segmento 1: 62 vehículos
#     Segmento 2: 56 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 63 vehículos
#   Calle 5 - Total Vehículos: 299
#     Segmento 1: 77 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 65 vehículos
#     Segmento 4: 75 vehículos
# Vecindario 3 - Total Vehículos: 1454
#   Calle 1 - Total Vehículos: 286
#     Segmento 1: 58 vehículos
#     Segmento 2: 84 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 300
#     Segmento 1: 68 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 87 vehículos
#   Calle 3 - Total Vehículos: 301
#     Segmento 1: 71 vehículos
#     Segmento 2: 83 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 277
#     Segmento 1: 50 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 290
#     Segmento 1: 65 vehículos
#     Segmento 2: 92 vehículos
#     Segmento 3: 76 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 18 ---
# Vecindario 1 - Total Vehículos: 1437
#   Calle 1 - Total Vehículos: 286
#     Segmento 1: 64 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 275
#     Segmento 1: 65 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 72 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 266
#     Segmento 1: 55 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 76 vehículos
#   Calle 4 - Total Vehículos: 302
#     Segmento 1: 72 vehículos
#     Segmento 2: 71 vehículos
#     Segmento 3: 87 vehículos
#     Segmento 4: 72 vehículos
#   Calle 5 - Total Vehículos: 308
#     Segmento 1: 62 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 85 vehículos
# Vecindario 2 - Total Vehículos: 1442
#   Calle 1 - Total Vehículos: 293
#     Segmento 1: 81 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 70 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 310
#     Segmento 1: 77 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 290
#     Segmento 1: 69 vehículos
#     Segmento 2: 69 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 77 vehículos
#   Calle 4 - Total Vehículos: 253
#     Segmento 1: 61 vehículos
#     Segmento 2: 55 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 62 vehículos
#   Calle 5 - Total Vehículos: 296
#     Segmento 1: 76 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 74 vehículos
# Vecindario 3 - Total Vehículos: 1443
#   Calle 1 - Total Vehículos: 284
#     Segmento 1: 57 vehículos
#     Segmento 2: 83 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 297
#     Segmento 1: 67 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 86 vehículos
#   Calle 3 - Total Vehículos: 299
#     Segmento 1: 70 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 276
#     Segmento 1: 49 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 287
#     Segmento 1: 64 vehículos
#     Segmento 2: 91 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 19 ---
# Vecindario 1 - Total Vehículos: 1425
#   Calle 1 - Total Vehículos: 284
#     Segmento 1: 63 vehículos
#     Segmento 2: 66 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 273
#     Segmento 1: 64 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 71 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 264
#     Segmento 1: 54 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 75 vehículos
#   Calle 4 - Total Vehículos: 298
#     Segmento 1: 71 vehículos
#     Segmento 2: 70 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 71 vehículos
#   Calle 5 - Total Vehículos: 306
#     Segmento 1: 61 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 84 vehículos
# Vecindario 2 - Total Vehículos: 1428
#   Calle 1 - Total Vehículos: 291
#     Segmento 1: 80 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 69 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 308
#     Segmento 1: 76 vehículos
#     Segmento 2: 81 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 286
#     Segmento 1: 68 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 74 vehículos
#     Segmento 4: 76 vehículos
#   Calle 4 - Total Vehículos: 250
#     Segmento 1: 60 vehículos
#     Segmento 2: 54 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 61 vehículos
#   Calle 5 - Total Vehículos: 293
#     Segmento 1: 75 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 63 vehículos
#     Segmento 4: 73 vehículos
# Vecindario 3 - Total Vehículos: 1432
#   Calle 1 - Total Vehículos: 282
#     Segmento 1: 56 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 294
#     Segmento 1: 66 vehículos
#     Segmento 2: 66 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 85 vehículos
#   Calle 3 - Total Vehículos: 297
#     Segmento 1: 69 vehículos
#     Segmento 2: 81 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 275
#     Segmento 1: 48 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 284
#     Segmento 1: 63 vehículos
#     Segmento 2: 90 vehículos
#     Segmento 3: 74 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 20 ---
# Vecindario 1 - Total Vehículos: 1413
#   Calle 1 - Total Vehículos: 282
#     Segmento 1: 62 vehículos
#     Segmento 2: 65 vehículos
#     Segmento 3: 86 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 271
#     Segmento 1: 63 vehículos
#     Segmento 2: 68 vehículos
#     Segmento 3: 70 vehículos
#     Segmento 4: 70 vehículos
#   Calle 3 - Total Vehículos: 262
#     Segmento 1: 53 vehículos
#     Segmento 2: 74 vehículos
#     Segmento 3: 61 vehículos
#     Segmento 4: 74 vehículos
#   Calle 4 - Total Vehículos: 294
#     Segmento 1: 70 vehículos
#     Segmento 2: 69 vehículos
#     Segmento 3: 85 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 304
#     Segmento 1: 60 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 81 vehículos
#     Segmento 4: 83 vehículos
# Vecindario 2 - Total Vehículos: 1414
#   Calle 1 - Total Vehículos: 289
#     Segmento 1: 79 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 68 vehículos
#     Segmento 4: 69 vehículos
#   Calle 2 - Total Vehículos: 306
#     Segmento 1: 75 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 78 vehículos
#   Calle 3 - Total Vehículos: 282
#     Segmento 1: 67 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 75 vehículos
#   Calle 4 - Total Vehículos: 247
#     Segmento 1: 59 vehículos
#     Segmento 2: 53 vehículos
#     Segmento 3: 75 vehículos
#     Segmento 4: 60 vehículos
#   Calle 5 - Total Vehículos: 290
#     Segmento 1: 74 vehículos
#     Segmento 2: 82 vehículos
#     Segmento 3: 62 vehículos
#     Segmento 4: 72 vehículos
# Vecindario 3 - Total Vehículos: 1421
#   Calle 1 - Total Vehículos: 280
#     Segmento 1: 55 vehículos
#     Segmento 2: 81 vehículos
#     Segmento 3: 79 vehículos
#     Segmento 4: 65 vehículos
#   Calle 2 - Total Vehículos: 291
#     Segmento 1: 65 vehículos
#     Segmento 2: 65 vehículos
#     Segmento 3: 77 vehículos
#     Segmento 4: 84 vehículos
#   Calle 3 - Total Vehículos: 295
#     Segmento 1: 68 vehículos
#     Segmento 2: 80 vehículos
#     Segmento 3: 64 vehículos
#     Segmento 4: 83 vehículos
#   Calle 4 - Total Vehículos: 274
#     Segmento 1: 47 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 78 vehículos
#     Segmento 4: 82 vehículos
#   Calle 5 - Total Vehículos: 281
#     Segmento 1: 62 vehículos
#     Segmento 2: 89 vehículos
#     Segmento 3: 73 vehículos
#     Segmento 4: 57 vehículos
#
#
# --- Ciclo 21 ---
# Vecindario 1 - Total Vehículos: 1400
#   Calle 1 - Total Vehículos: 279
#     Segmento 1: 61 vehículos
#     Segmento 2: 65 vehículos
#     Segmento 3: 85 vehículos
#     Segmento 4: 68 vehículos
#   Calle 2 - Total Vehículos: 268
#     Segmento 1: 62 vehículos
#     Segmento 2: 67 vehículos
#     Segmento 3: 70 vehículos
#     Segmento 4: 69 vehículos
#   Calle 3 - Total Vehículos: 259
#     Segmento 1: 52 vehículos
#     Segmento 2: 73 vehículos
#     Segmento 3: 60 vehículos
#     Segmento 4: 74 vehículos
#   Calle 4 - Total Vehículos: 293
#     Segmento 1: 69 vehículos
#     Segmento 2: 69 vehículos
#     Segmento 3: 85 vehículos
#     Segmento 4: 70 vehículos
#   Calle 5 - Total Vehículos: 301
# ...
#     Segmento 2: 34 vehículos
#     Segmento 3: 21 vehículos
#     Segmento 4: 40 vehículos
#   Calle 4 - Total Vehículos: 122
#     Segmento 1: 0 vehículos
#     Segmento 2: 35 vehículos
#     Segmento 3: 51 vehículos
#     Segmento 4: 36 vehículos
#   Calle 5 - Total Vehículos: 130
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 41 vehículos
#     Segmento 4: 49 vehículos
# Vecindario 2 - Total Vehículos: 520
#   Calle 1 - Total Vehículos: 101
#     Segmento 1: 5 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 34 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 118
#     Segmento 1: 1 vehículos
#     Segmento 2: 46 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 38 vehículos
#   Calle 3 - Total Vehículos: 113
#     Segmento 1: 0 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 41 vehículos
#   Calle 4 - Total Vehículos: 80
#     Segmento 1: 0 vehículos
#     Segmento 2: 19 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 26 vehículos
#   Calle 5 - Total Vehículos: 108
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 28 vehículos
#     Segmento 4: 38 vehículos
# Vecindario 3 - Total Vehículos: 560
#   Calle 1 - Total Vehículos: 111
#     Segmento 1: 0 vehículos
#     Segmento 2: 47 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 25 vehículos
#   Calle 2 - Total Vehículos: 118
#     Segmento 1: 0 vehículos
#     Segmento 2: 31 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 50 vehículos
#   Calle 3 - Total Vehículos: 113
#     Segmento 1: 0 vehículos
#     Segmento 2: 46 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 43 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 42 vehículos
#   Calle 5 - Total Vehículos: 111
#     Segmento 1: 0 vehículos
#     Segmento 2: 55 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 17 vehículos
#
#
# --- Ciclo 95 ---
# Vecindario 1 - Total Vehículos: 540
#   Calle 1 - Total Vehículos: 105
#     Segmento 1: 0 vehículos
#     Segmento 2: 30 vehículos
#     Segmento 3: 46 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 93
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 30 vehículos
#   Calle 3 - Total Vehículos: 94
#     Segmento 1: 0 vehículos
#     Segmento 2: 34 vehículos
#     Segmento 3: 21 vehículos
#     Segmento 4: 39 vehículos
#   Calle 4 - Total Vehículos: 119
#     Segmento 1: 0 vehículos
#     Segmento 2: 34 vehículos
#     Segmento 3: 50 vehículos
#     Segmento 4: 35 vehículos
#   Calle 5 - Total Vehículos: 129
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 41 vehículos
#     Segmento 4: 48 vehículos
# Vecindario 2 - Total Vehículos: 509
#   Calle 1 - Total Vehículos: 99
#     Segmento 1: 4 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 116
#     Segmento 1: 0 vehículos
#     Segmento 2: 45 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 38 vehículos
#   Calle 3 - Total Vehículos: 110
#     Segmento 1: 0 vehículos
#     Segmento 2: 32 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 40 vehículos
#   Calle 4 - Total Vehículos: 78
#     Segmento 1: 0 vehículos
#     Segmento 2: 18 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 25 vehículos
#   Calle 5 - Total Vehículos: 106
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 27 vehículos
#     Segmento 4: 37 vehículos
# Vecindario 3 - Total Vehículos: 554
#   Calle 1 - Total Vehículos: 110
#     Segmento 1: 0 vehículos
#     Segmento 2: 46 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 25 vehículos
#   Calle 2 - Total Vehículos: 116
#     Segmento 1: 0 vehículos
#     Segmento 2: 30 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 49 vehículos
#   Calle 3 - Total Vehículos: 112
#     Segmento 1: 0 vehículos
#     Segmento 2: 45 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 43 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 42 vehículos
#   Calle 5 - Total Vehículos: 109
#     Segmento 1: 0 vehículos
#     Segmento 2: 54 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 17 vehículos
#
#
# --- Ciclo 96 ---
# Vecindario 1 - Total Vehículos: 533
#   Calle 1 - Total Vehículos: 104
#     Segmento 1: 0 vehículos
#     Segmento 2: 29 vehículos
#     Segmento 3: 46 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 92
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 34 vehículos
#     Segmento 4: 30 vehículos
#   Calle 3 - Total Vehículos: 93
#     Segmento 1: 0 vehículos
#     Segmento 2: 34 vehículos
#     Segmento 3: 21 vehículos
#     Segmento 4: 38 vehículos
#   Calle 4 - Total Vehículos: 116
#     Segmento 1: 0 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 49 vehículos
#     Segmento 4: 34 vehículos
#   Calle 5 - Total Vehículos: 128
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 41 vehículos
#     Segmento 4: 47 vehículos
# Vecindario 2 - Total Vehículos: 499
#   Calle 1 - Total Vehículos: 97
#     Segmento 1: 3 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 32 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 115
#     Segmento 1: 0 vehículos
#     Segmento 2: 44 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 38 vehículos
#   Calle 3 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 31 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 39 vehículos
#   Calle 4 - Total Vehículos: 76
#     Segmento 1: 0 vehículos
#     Segmento 2: 17 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 24 vehículos
#   Calle 5 - Total Vehículos: 104
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 26 vehículos
#     Segmento 4: 36 vehículos
# Vecindario 3 - Total Vehículos: 548
#   Calle 1 - Total Vehículos: 109
#     Segmento 1: 0 vehículos
#     Segmento 2: 45 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 25 vehículos
#   Calle 2 - Total Vehículos: 114
#     Segmento 1: 0 vehículos
#     Segmento 2: 29 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 48 vehículos
#   Calle 3 - Total Vehículos: 111
#     Segmento 1: 0 vehículos
#     Segmento 2: 44 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 43 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 42 vehículos
#   Calle 5 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 53 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 17 vehículos
#
#
# --- Ciclo 97 ---
# Vecindario 1 - Total Vehículos: 526
#   Calle 1 - Total Vehículos: 103
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 46 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 91
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 30 vehículos
#   Calle 3 - Total Vehículos: 92
#     Segmento 1: 0 vehículos
#     Segmento 2: 34 vehículos
#     Segmento 3: 21 vehículos
#     Segmento 4: 37 vehículos
#   Calle 4 - Total Vehículos: 113
#     Segmento 1: 0 vehículos
#     Segmento 2: 32 vehículos
#     Segmento 3: 48 vehículos
#     Segmento 4: 33 vehículos
#   Calle 5 - Total Vehículos: 127
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 41 vehículos
#     Segmento 4: 46 vehículos
# Vecindario 2 - Total Vehículos: 489
#   Calle 1 - Total Vehículos: 95
#     Segmento 1: 2 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 31 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 114
#     Segmento 1: 0 vehículos
#     Segmento 2: 43 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 38 vehículos
#   Calle 3 - Total Vehículos: 104
#     Segmento 1: 0 vehículos
#     Segmento 2: 30 vehículos
#     Segmento 3: 36 vehículos
#     Segmento 4: 38 vehículos
#   Calle 4 - Total Vehículos: 74
#     Segmento 1: 0 vehículos
#     Segmento 2: 16 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 23 vehículos
#   Calle 5 - Total Vehículos: 102
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 25 vehículos
#     Segmento 4: 35 vehículos
# Vecindario 3 - Total Vehículos: 542
#   Calle 1 - Total Vehículos: 108
#     Segmento 1: 0 vehículos
#     Segmento 2: 44 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 25 vehículos
#   Calle 2 - Total Vehículos: 112
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 47 vehículos
#   Calle 3 - Total Vehículos: 110
#     Segmento 1: 0 vehículos
#     Segmento 2: 43 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 43 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 42 vehículos
#   Calle 5 - Total Vehículos: 105
#     Segmento 1: 0 vehículos
#     Segmento 2: 52 vehículos
#     Segmento 3: 36 vehículos
#     Segmento 4: 17 vehículos
#
#
# --- Ciclo 98 ---
# Vecindario 1 - Total Vehículos: 519
#   Calle 1 - Total Vehículos: 102
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 46 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 90
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 32 vehículos
#     Segmento 4: 30 vehículos
#   Calle 3 - Total Vehículos: 91
#     Segmento 1: 0 vehículos
#     Segmento 2: 34 vehículos
#     Segmento 3: 21 vehículos
#     Segmento 4: 36 vehículos
#   Calle 4 - Total Vehículos: 110
#     Segmento 1: 0 vehículos
#     Segmento 2: 31 vehículos
#     Segmento 3: 47 vehículos
#     Segmento 4: 32 vehículos
#   Calle 5 - Total Vehículos: 126
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 41 vehículos
#     Segmento 4: 45 vehículos
# Vecindario 2 - Total Vehículos: 479
#   Calle 1 - Total Vehículos: 93
#     Segmento 1: 1 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 30 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 113
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 38 vehículos
#   Calle 3 - Total Vehículos: 101
#     Segmento 1: 0 vehículos
#     Segmento 2: 29 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 37 vehículos
#   Calle 4 - Total Vehículos: 72
#     Segmento 1: 0 vehículos
#     Segmento 2: 15 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 22 vehículos
#   Calle 5 - Total Vehículos: 100
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 34 vehículos
# Vecindario 3 - Total Vehículos: 536
#   Calle 1 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 43 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 25 vehículos
#   Calle 2 - Total Vehículos: 110
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 46 vehículos
#   Calle 3 - Total Vehículos: 109
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 43 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 42 vehículos
#   Calle 5 - Total Vehículos: 103
#     Segmento 1: 0 vehículos
#     Segmento 2: 51 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 17 vehículos
#
#
# --- Ciclo 99 ---
# Vecindario 1 - Total Vehículos: 512
#   Calle 1 - Total Vehículos: 101
#     Segmento 1: 0 vehículos
#     Segmento 2: 26 vehículos
#     Segmento 3: 46 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 89
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 31 vehículos
#     Segmento 4: 30 vehículos
#   Calle 3 - Total Vehículos: 90
#     Segmento 1: 0 vehículos
#     Segmento 2: 34 vehículos
#     Segmento 3: 21 vehículos
#     Segmento 4: 35 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 30 vehículos
#     Segmento 3: 46 vehículos
#     Segmento 4: 31 vehículos
#   Calle 5 - Total Vehículos: 125
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 41 vehículos
#     Segmento 4: 44 vehículos
# Vecindario 2 - Total Vehículos: 469
#   Calle 1 - Total Vehículos: 91
#     Segmento 1: 0 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 29 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 112
#     Segmento 1: 0 vehículos
#     Segmento 2: 41 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 38 vehículos
#   Calle 3 - Total Vehículos: 98
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 34 vehículos
#     Segmento 4: 36 vehículos
#   Calle 4 - Total Vehículos: 70
#     Segmento 1: 0 vehículos
#     Segmento 2: 14 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 21 vehículos
#   Calle 5 - Total Vehículos: 98
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 23 vehículos
#     Segmento 4: 33 vehículos
# Vecindario 3 - Total Vehículos: 530
#   Calle 1 - Total Vehículos: 106
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 25 vehículos
#   Calle 2 - Total Vehículos: 108
#     Segmento 1: 0 vehículos
#     Segmento 2: 26 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 45 vehículos
#   Calle 3 - Total Vehículos: 108
#     Segmento 1: 0 vehículos
#     Segmento 2: 41 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 43 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 42 vehículos
#   Calle 5 - Total Vehículos: 101
#     Segmento 1: 0 vehículos
#     Segmento 2: 50 vehículos
#     Segmento 3: 34 vehículos
#     Segmento 4: 17 vehículos
#
#
# --- Ciclo 100 ---
# Vecindario 1 - Total Vehículos: 505
#   Calle 1 - Total Vehículos: 100
#     Segmento 1: 0 vehículos
#     Segmento 2: 25 vehículos
#     Segmento 3: 46 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 88
#     Segmento 1: 0 vehículos
#     Segmento 2: 28 vehículos
#     Segmento 3: 30 vehículos
#     Segmento 4: 30 vehículos
#   Calle 3 - Total Vehículos: 89
#     Segmento 1: 0 vehículos
#     Segmento 2: 34 vehículos
#     Segmento 3: 21 vehículos
#     Segmento 4: 34 vehículos
#   Calle 4 - Total Vehículos: 104
#     Segmento 1: 0 vehículos
#     Segmento 2: 29 vehículos
#     Segmento 3: 45 vehículos
#     Segmento 4: 30 vehículos
#   Calle 5 - Total Vehículos: 124
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 41 vehículos
#     Segmento 4: 43 vehículos
# Vecindario 2 - Total Vehículos: 460
#   Calle 1 - Total Vehículos: 90
#     Segmento 1: 0 vehículos
#     Segmento 2: 33 vehículos
#     Segmento 3: 28 vehículos
#     Segmento 4: 29 vehículos
#   Calle 2 - Total Vehículos: 111
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 38 vehículos
#   Calle 3 - Total Vehículos: 95
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 35 vehículos
#   Calle 4 - Total Vehículos: 68
#     Segmento 1: 0 vehículos
#     Segmento 2: 13 vehículos
#     Segmento 3: 35 vehículos
#     Segmento 4: 20 vehículos
#   Calle 5 - Total Vehículos: 96
#     Segmento 1: 0 vehículos
#     Segmento 2: 42 vehículos
#     Segmento 3: 22 vehículos
#     Segmento 4: 32 vehículos
# Vecindario 3 - Total Vehículos: 524
#   Calle 1 - Total Vehículos: 105
#     Segmento 1: 0 vehículos
#     Segmento 2: 41 vehículos
#     Segmento 3: 39 vehículos
#     Segmento 4: 25 vehículos
#   Calle 2 - Total Vehículos: 106
#     Segmento 1: 0 vehículos
#     Segmento 2: 25 vehículos
#     Segmento 3: 37 vehículos
#     Segmento 4: 44 vehículos
#   Calle 3 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 40 vehículos
#     Segmento 3: 24 vehículos
#     Segmento 4: 43 vehículos
#   Calle 4 - Total Vehículos: 107
#     Segmento 1: 0 vehículos
#     Segmento 2: 27 vehículos
#     Segmento 3: 38 vehículos
#     Segmento 4: 42 vehículos
#   Calle 5 - Total Vehículos: 99
#     Segmento 1: 0 vehículos
#     Segmento 2: 49 vehículos
#     Segmento 3: 33 vehículos
#     Segmento 4: 17 vehículos

# %% [markdown]
# ### Función para generar un resumen más limpio de la simulación.

# %%
def generar_resumen(resultados, ciudad):
    primer_ciclo = resultados["Ciclo 1"]
    ultimo_ciclo = resultados[f"Ciclo {num_ciclos}"]

    # Extraer todos los vehículos de la ciudad
    todos_los_vehiculos = [
        vehiculo
        for vecindario in ciudad.vecindarios
        for calle in vecindario.calles
        for segmento in calle.segmentos
        for vehiculo in segmento.vehiculos
    ]

    # Contar los comportamientos
    conteo_comportamientos = {
        "cauteloso": 0,
        "normal": 0,
        "agresivo": 0
    }

    for vehiculo in todos_los_vehiculos:
        conteo_comportamientos[vehiculo.comportamiento] += 1

    total_vehiculos = sum(conteo_comportamientos.values())

    # Número total de vehículos en la ciudad al principio y al final
    total_vehiculos_inicio = sum(
        sum(datos_calle.values())
        for datos_vecindario in primer_ciclo.values()
        for datos_calle in datos_vecindario.values()
    )
    total_vehiculos_final = sum(
        sum(datos_calle.values())
        for datos_vecindario in ultimo_ciclo.values()
        for datos_calle in datos_vecindario.values()
    )

    # Promedio de vehículos por segmento al principio y al final
    total_segmentos = sum(
        len(datos_vecindario) for datos_vecindario in primer_ciclo.values()
    )
    promedio_vehiculos_inicio = total_vehiculos_inicio / total_segmentos
    promedio_vehiculos_final = total_vehiculos_final / total_segmentos

    # Segmentos con mayor y menor cantidad de vehículos al final
    todos_los_segmentos = [
        (vecindario, calle, segmento, vehiculos)
        for vecindario, datos_vecindario in ultimo_ciclo.items()
        for calle, datos_calle in datos_vecindario.items()
        for segmento, vehiculos in datos_calle.items()
    ]
    segmento_mas_congestionado = max(todos_los_segmentos, key=lambda x: x[3])
    segmento_menos_congestionado = min(todos_los_segmentos, key=lambda x: x[3])

    # Imprimir resumen
    print(f"Total de vehículos al inicio: {total_vehiculos_inicio}")
    print(f"Total de vehículos al final: {total_vehiculos_final}")
    print(
        f"Promedio de vehículos por segmento al inicio: {promedio_vehiculos_inicio:.2f}"
    )
    print(
        f"Promedio de vehículos por segmento al final: {promedio_vehiculos_final:.2f}"
    )
    print(
        f"\nSegmento más congestionado al final: {segmento_mas_congestionado[0]} > {segmento_mas_congestionado[1]} > {segmento_mas_congestionado[2]} con {segmento_mas_congestionado[3]} vehículos"
    )
    print(
        f"Segmento menos congestionado al final: {segmento_menos_congestionado[0]} > {segmento_menos_congestionado[1]} > {segmento_menos_congestionado[2]} con {segmento_menos_congestionado[3]} vehículos"
    )

    # Información sobre el comportamiento de los vehículos
    print("\nComportamiento de los vehículos al final de la simulación:")
    for comportamiento, cantidad in conteo_comportamientos.items():
        porcentaje = (cantidad / total_vehiculos) * 100
        print(f"{comportamiento.capitalize()}: {cantidad} vehículos ({porcentaje:.2f}%)")

    print("\nObservaciones:")
    if conteo_comportamientos["agresivo"] > conteo_comportamientos["cauteloso"]:
        print("- Hay más vehículos con comportamiento agresivo que cauteloso. Esto puede haber incrementado la congestión en ciertas áreas.")
    else:
        print("- Hay más vehículos con comportamiento cauteloso que agresivo. Esto puede haber contribuido a un flujo de tráfico más suave en algunas zonas.")
    if conteo_comportamientos["normal"] > total_vehiculos * 0.5:
        print("- La mayoría de los vehículos tienen un comportamiento normal, indicando un equilibrio en la dinámica del tráfico.")


# Llamar a la función de resumen después de la simulación
generar_resumen(resultados, ciudad)
# Out:
# Total de vehículos al inicio: 4960
# Total de vehículos al final: 1489
# Promedio de vehículos por segmento al inicio: 330.67
# Promedio de vehículos por segmento al final: 99.27
#
# Segmento más congestionado al final: Vecindario 3 > Calle 5 > Segmento 2 con 49 vehículos
# Segmento menos congestionado al final: Vecindario 1 > Calle 1 > Segmento 1 con 0 vehículos
#
# Comportamiento de los vehículos al final de la simulación:
# Cauteloso: 513 vehículos (34.45%)
# Normal: 476 vehículos (31.97%)
# Agresivo: 500 vehículos (33.58%)
#
# Observaciones:
# - Hay más vehículos con comportamiento cauteloso que agresivo. Esto puede haber contribuido a un flujo de tráfico más suave en algunas zonas.

# %% [markdown]
# ## Respuestas a preguntas

# %% [markdown]
# 1. ¿Qué es el modelado multiescala y por qué es valioso para comprender el flujo y la congestión del tráfico urbano?
#
#     El modelado multiescala es un enfoque que modela sistemas complejos en diferentes escalas, permitiendo representar tanto los detalles finos (microescala) como el panorama general (macroescala). En el contexto del tráfico urbano, este enfoque es valioso porque la dinámica del tráfico puede ser influenciada por factores a diferentes niveles: desde decisiones individuales de los conductores hasta patrones de tráfico a nivel de ciudad. Al abordar cada escala, el modelado multiescala puede proporcionar una comprensión más detallada y precisa del flujo de tráfico y la congestión.

# %% [markdown]
# 2. Describe el modelo individual a nivel de vehículo en esta simulación multiescala. ¿Qué parámetros y factores se consideran a esta escala?
#
#     A nivel de vehículo, la simulación se enfoca en el comportamiento individual de cada vehículo. En el modelo:
#
#     - Cada vehículo tiene un *tipo_vehiculo*, aunque en este caso siempre se inicia como "coche".
#
#     - Se define una *velocidad_maxima*.
#
#     - Se registra la *velocidad_actual* del vehículo.
#
#     - El vehículo tiene un comportamiento específico, que puede ser "cauteloso", "normal" o "agresivo".
#
#     Este comportamiento determina cómo acelera o desacelera el vehículo en diferentes circunstancias.
#
#     Los vehículos tienen la capacidad de acelerar (acelerar) o desacelerar (desacelerar) en función de su comportamiento y las condiciones del tráfico.

# %% [markdown]
# 3. Explique el modelo a nivel de segmento de carretera. ¿Cómo tiene en cuenta la densidad del tráfico, los límites de velocidad y la congestión?
#
#     - Cada segmento de carretera tiene una *capacidad* máxima de vehículos y un *limite_velocidad*.
#
#     - La densidad del tráfico se monitorea a través de la cantidad de vehículos en el segmento (*num_vehiculos*).
#
#     - Si la cantidad de vehículos excede el 80% de la capacidad del segmento, se considera que hay congestion. Cuando hay congestión, los vehículos desaceleran.
#
#     - El flujo de vehículos (flujo_vehiculos) se regula en función de la congestión y la velocidad actual de los vehículos. Si no hay congestión y la velocidad actual del vehículo es menor que el límite, el vehículo puede acelerar. En caso contrario, puede desacelerar.

# %% [markdown]
# 4. Analice el modelo a nivel de intersección. ¿Qué variables se tienen en cuenta al simular las interacciones de vehículos en las intersecciones?
#
#     - Cada intersección tiene un semáforo (*semaforo*) que puede estar en "rojo" o "verde".
#
#     - Hay un contador (*tiempo_semaforo*) que controla cuándo cambiar el estado del semáforo. En este modelo, el semáforo cambia de estado cada 10 ciclos.
#
#     - Los vehículos que esperan en una intersección se almacenan en *vehiculos_esperando*.
#
#     - Si el semáforo está en verde, y hay vehículos esperando, un vehículo será movido al siguiente segmento (*manejar_interseccion*).
